# %% [markdown]
# <a href="https://colab.research.google.com/github/rps007/How-to-Load-the-DeepSeek-R1-Model-in-Google-Colab-Using-Ollama-Step-by-Step-Tutorial/blob/main/connect2github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **connect to github**

# %%
from google.colab import userdata
import os

# get token and email - token and gitemail have to be stored as secrets in the colab keys
token = userdata.get('gittoken')
gitemail = userdata.get('gitemail')

# !git config --global user.name „rps007“
# !git config --global user.email {gitemail}

repo = "docx_correct" # fill in repo
username = "rps007"
username = 'timleibold'
repository = f"https://github.com/{username}/{repo}.git"


# Using the token for cloning
# !git clone https://{username}:{token}@github.com/{username}/{repo}.git

# change path of the working directory
repo = repository.split('/')[-1].split('.')[0]
folder = f"/content/{repo}"
os.chdir(folder)

print(f"\nCurrent working directory set to: {os.getcwd()}")
# Out:
# Cloning into 'docx_correct'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 38 (delta 13), reused 33 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (38/38), 64.80 KiB | 2.95 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
#
# Current working directory set to: /content/docx_correct

# %% [markdown]
# #### **push to github**

# %%
# !git add .
# !git commit -m "Your commit message"
# !git push origin main  # Or your branch name!git commit -m "Your commit message"

# %% [markdown]
# !git add .
# !git commit -m "Your commit message"
# !git push origin main  # Or your branch name!git commit -m "Your commit message"
